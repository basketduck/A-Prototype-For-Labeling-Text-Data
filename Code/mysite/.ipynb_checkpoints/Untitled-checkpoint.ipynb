# %%
import csv
import smart_open
import gensim
from collections import defaultdict
from gensim import corpora

with smart_open.open('/Users/hiphone/Downloads/ads-100,000.csv') as f:
    ads_csv = csv.reader(f, delimiter = ',')
    headers = next(ads_csv)
    documents = list(map(lambda x: x[1], ads_csv))

# %%
model = gensim.models.doc2vec.Doc2Vec.load('/Users/hiphone/fb_10w_d100_e10.d2v')

# %%
selected_document_id = 3
print(documents[selected_document_id])
# Out:
# Hey There! We know you really wanted this beautiful Trump 2020 Law and Order Premium Sherpa Blanket and thought we would help you out! 🛒
#
# Click on shop now and get a matching 3x5" Single reverse flag with it. 🇺🇸
# ⏲️Limited Time Offer Only! Get Yours Today! ⏲️
#
# Shop Now => doperage.com/trump-law-and-order-blanket-with-flag

# %%
similar_docs = list(map(lambda x: x[0], model.docvecs.most_similar(selected_document_id, topn = 10)))
print(documents[selected_document_id])
print('---------')
for i in similar_docs:
    print(documents[i])
    print('---------')
# Out:
# Hey There! We know you really wanted this beautiful Trump 2020 Law and Order Premium Sherpa Blanket and thought we would help you out! 🛒
#
# Click on shop now and get a matching 3x5" Single reverse flag with it. 🇺🇸
# ⏲️Limited Time Offer Only! Get Yours Today! ⏲️
#
# Shop Now => doperage.com/trump-law-and-order-blanket-with-flag
# ---------
# Hey There! We know you really wanted this beautiful Trump 2020 Law and Order Premium Sherpa Blanket and thought we would help you out! 🛒
#
# Click on shop now and get a matching 3x5" Single reverse flag with it. 🇺🇸
# ⏲️Limited Time Offer Only! Get Yours Today! ⏲️
#
# Shop Now => doperage.com/trump-law-and-order-blanket-with-flag
# ---------
# Hey There! We know you really wanted this beautiful Trump 2020 Law and Order Premium Sherpa Blanket and thought we would help you out! 🛒
#
# Click on shop now and get a matching 3x5" Single reverse flag with it. 🇺🇸
# ⏲️Limited Time Offer Only! Get Yours Today! ⏲️
#
# Shop Now => doperage.com/trump-law-and-order-blanket-with-flag
# ---------
# Hey There! We know you really wanted this beautiful Betsy Ross Premium Sherpa Blanket and thought we would help you out! 🛒
#
# Click on shop now and get a matching 3x5" Single reverse flag with it. 🇺🇸
# ⏲️Limited Time Offer Only! Get Yours Today! ⏲️
#
# Shop Now => doperage.com/betsyross-blanket-with-flag
# ---------
# Bee Kind 🐝 Help us spread this message ❤️ New yellow sweatshirt available in the store. Grab yours before it’s gone. Shop now!
# .
# 🐮 10% of our profits go to animal rescue and environmental organizations
# 🌿 Made from organic cotton and recycled materials
# ✌️ Ethically Made
# .
# 💑 Order with your best friend and save on shipping!
# ---------
# Hey! 🇺🇸 Noticed ya checked out our 2nd Amendment Law and Order BUNDLE... but decided not to grab it.
#
# So we wanted to give you 15% OFF Your ENTIRE ORDER!
#
# It's time to take a stand and keep America great! 🇺🇸
#
# Just Use Code: FREEDOM @ Checkout 🤙
#
# 👉👉👉 https://bit.ly/2vR58QZ
# ---------
# Support our President on his road to 2020! Premium double-sided law and order flag and camo hat bundle!🔥⏰
#
# TRUMP EXCLUSIVE BUNDLE - PREMIUM DOUBLE-SIDED LAW AND ORDER FLAG + TRUMP CAMO HAT COMBO➡
# https://doperage.com/Premium-Doublesided-LAO-Camo-Hat-Bundle
#
# See our premium flag collection here!➡ https://doperage.com/Premium-Double-Sided-3x5-Flags
#
# 💯 100% Brand new and high quality.
# 🌟Double-Sided with sunshade fabric in the middle for extra durability.
# ✈ Ships directly from the U.S.
# 🤩 100% Satisfaction Guaranteed!
# 🎁 Perfect Gift for Friends and Family
# ---------
# Support our President on his road to 2020! Premium double-sided law and order flag and camo hat bundle!🔥⏰
#
# TRUMP EXCLUSIVE BUNDLE - PREMIUM DOUBLE-SIDED LAW AND ORDER FLAG + TRUMP CAMO HAT COMBO➡
# https://doperage.com/Premium-Doublesided-LAO-Camo-Hat-Bundle
#
# See our premium flag collection here!➡ https://doperage.com/Premium-Double-Sided-3x5-Flags
#
# 💯 100% Brand new and high quality.
# 🌟Double-Sided with sunshade fabric in the middle for extra durability.
# ✈ Ships directly from the U.S.
# 🤩 100% Satisfaction Guaranteed!
# 🎁 Perfect Gift for Friends and Family
# ---------
# Hey! 🇺🇸 Noticed ya checked out our 2nd Amendment Law and Order BUNDLE... but decided not to grab it.
#
# So we wanted to give you 15% OFF Your ENTIRE ORDER!
#
# It's time to take a stand and keep America great! 🇺🇸
#
# Just Use Code: FREEDOM @ Checkout 🤙
#
# 👉👉👉 https://bit.ly/2vR58QZ
# ---------
# Show your support for Betsy Ross & The Gadsden Flag. Available for a limited time only. Click Shop Now to order yours!
# ---------
# Authentic Kryptek 2nd Amendment Hat
# You Can Get Yours Here:
# outergoods.com/products/og330hat
# ---------
# Yellow Blazer Dress With Gold Buckle Belt
# Size 6, 8 and 10 available 🔍 “Yellow “ in www.jazaafriq.com
# ---------
# Bee Kind 🐝 Spread this message ❤️ Shop Now! (New version available 😍)
# .
# 🐮 10% of our profits go to animal rescue and environmental organizations
# 🌿 Made from organic and recycled materials
# ✌️ Ethically Made
# .
# 💑 Order with your best friend and save on shipping!
# ---------
# Support our President on his road to 2020! Premium double-sided law and order flag and camo hat bundle!🔥⏰
#
# TRUMP EXCLUSIVE BUNDLE - PREMIUM DOUBLE-SIDED LAW AND ORDER FLAG + TRUMP CAMO HAT COMBO➡
# https://doperage.com/Premium-Doublesided-LAO-Camo-Hat-Bundle
#
# See our premium flag collection here!➡ https://doperage.com/Premium-Double-Sided-3x5-Flags
#
# 💯 100% Brand new and high quality.
# 🌟Double-Sided with sunshade fabric in the middle for extra durability.
# ✈ Ships directly from the U.S.
# 🤩 100% Satisfaction Guaranteed!
# 🎁 Perfect Gift for Friends and Family
# ---------
# Try the NEW Tru Earth Eco-Strips Laundry Detergent 🌳
#
# Did you know that over 700 million plastic laundry detergent jugs make their way into land fills and oceans every year in North America?
#
# Scary right?
#
# Join the Tru Earth movement and help us eliminate plastic jugs in landfills, one load of laundry at a time.
#
# Tru Earth Eco-Strips is a convenient new pre-measured eco-strip laundry detergent.
#
# Which means:
# ✅ No more measuring
# ✅ No more mess
# ✅ No more plastic jugs
# ✅ 94% smaller carbon footprint than traditional detergents
#
# Convenient FREE monthly deliveries so you never run out of detergent again
#
# Ready to join the Tru Earth movement and put an end to detergent jugs in landfills?
#
# Try Tru Earth Eco-Strips today 👉 https://www.tru.earth
# ---------
# Trump Declares National Emergency Over Southern Border. WE ARE GOING TO BUILD A WALL!
#
# Get Your FREE 3x5 Trump 2020 Keep America Great Flag
#
# Help Support TRUMP's 2020 Campaign With This Beuatiful FREE Flag, Act Fast This Offer Is Only Good While Supplies Last!
# ---------
# Spreadin' awareness for our planet's pollinators in style! 🐝👑
#
# Help save the bees with our best selling "BooBee" Tee!
#
# It's super comfortable & makes for an amazing gift! 🎁
#
# ➡️➡️➡️ educatedearthling.com/BooBee
# ---------
# Try the NEW Tru Earth Eco-Strips Laundry Detergent 🌳
#
# Did you know that over 700 million plastic laundry detergent jugs make their way into land fills and oceans every year in North America?
#
# Scary right?
#
# Join the Tru Earth movement and help us eliminate plastic jugs in landfills, one load of laundry at a time.
#
# Tru Earth Eco-Strips is a convenient new pre-measured eco-strip laundry detergent.
#
# Which means:
# ✅ No more measuring
# ✅ No more mess
# ✅ No more plastic jugs
# ✅ 94% smaller carbon footprint than traditional detergents
#
# Convenient FREE monthly deliveries so you never run out of detergent again
#
# Ready to join the Tru Earth movement and put an end to detergent jugs in landfills?
#
# Try Tru Earth Eco-Strips today 👉 https://www.tru.earth
# ---------
# Support Trump for President with this awesome Trump T Shirt.
# https://www.amazon.com/dp/B07Z84VZGW?ref=myi_title_dp
# ---------
# Trump 2020 , Autographed presidential Tumbler
# Lets make Liberals Cry Again!
#
# Available Here : http://shop.wordsengraved.com/trump
#
# These are limited, so we only have 485 available.
# If you cant add it to cart it means we are sold out.
# ---------
# 💚 Plastic Free Pamper Box 💚 indulge in the beautiful natural selection! Box includes our Shampoo & Conditioner, Hyaluronic Moisturiser, Detox Black Clay Mask, Anti-Ageing Eye Gel, Natural Detox Soap and our Argan Rich Lip Balm. Introductory offer of £49! Normally worth over £80. Treat yourself or gift it to someone special 💚 Only @greenplanet_beauty
#
# #vegan #teamnatural #veganlife #plasticfree #waronplastic #plasticfreeoceans #plasticfreeliving #plasticfreelife #plasticfreeuk #plasticfreeproduce #plasticfreeforthesea #plasticfreebeauty #bethechange🌎 #veganbeautyaddict #facecream #facemasks #vegan #govegan #crueltyfree #crueltyfreeliving #crueltyfreecosmetics #crueltyfreeskincare #crueltyfreebeauty #crueltyfreemakeup #crueltyfreeproducts #crueltyfreehair #climatechange #gretathunberg #substainable
# ---------

# %%
model.most_similar('ebola', topn=50)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('borne', 0.5874761939048767),
#  ('mahmoud', 0.5570811033248901),
#  ('vid', 0.5373464822769165),
#  ('stalled', 0.5305622220039368),
#  ('perpetuated', 0.5246564149856567),
#  ('poisonous', 0.5170691013336182),
#  ('𝗪𝗮𝗹𝗹𝐬', 0.5069310665130615),
#  ('philippines', 0.5064871311187744),
#  ('campaigned', 0.5039815902709961),
#  ('plummeted', 0.497468501329422),
#  ('zakaria', 0.49273285269737244),
#  ('𝗦𝗼𝗹𝗶𝗱', 0.4890580177307129),
#  ('watched', 0.4846698045730591),
#  ('intensified', 0.484306663274765),
#  ('characterized', 0.48185932636260986),
#  ('advantages', 0.48126256465911865),
#  ('grown', 0.47912681102752686),
#  ('surpassed', 0.4782247543334961),
#  ('hurricane', 0.4668303430080414),
#  ('gabriel', 0.46594929695129395),
#  ('eslami', 0.465688556432724),
#  ('declined', 0.46501436829566956),
#  ('plagued', 0.46175605058670044),
#  ('widespread', 0.4608931541442871),
#  ('brentwood', 0.4595801830291748),
#  ('idai', 0.45913463830947876),
#  ('captured', 0.457797646522522),
#  ('bombing', 0.45776641368865967),
#  ('kimball', 0.45732659101486206),
#  ('retaliate', 0.4539209306240082),
#  ('mohamed', 0.4534841477870941),
#  ('recovered', 0.45205560326576233),
#  ('epidemics', 0.4519067108631134),
#  ('extensively', 0.4511021375656128),
#  ('targeted', 0.45018014311790466),
#  ('alamo', 0.4492671489715576),
#  ('wwr', 0.44866833090782166),
#  ('botched', 0.448664128780365),
#  ('pentagon', 0.44844505190849304),
#  ('thomson', 0.44806602597236633),
#  ('inflicted', 0.44687870144844055),
#  ('emerged', 0.44652819633483887),
#  ('bushfires', 0.4459652006626129),
#  ('dam', 0.4452672600746155),
#  ('uncovered', 0.4450930655002594),
#  ('worsened', 0.4435628652572632),
#  ('accustomed', 0.4432849586009979),
#  ('interesting', 0.44178053736686707),
#  ('repeatedly', 0.4415090084075928),
#  ('fraught', 0.44142332673072815)]
